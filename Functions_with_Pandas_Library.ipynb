# %% [markdown]
# <a href="https://colab.research.google.com/github/faizazulfqar/Machine-Learning/blob/master/Functions_with_Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importing Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Numpy Library is used to create arrays and matrices. It makes homogeneous objects.
# Pandas Library is used for data manipulation and data analysis. It is used for creating hetrogeneous objects.
# Matplotlib is a plotting library used for visualization of data. Seaborn is also a data visualization library used for plotting based on matplotlib. And it provides highr interface than matplotlib. Seaborn also hold various default datasets.

# %% [markdown]
# ##Loading a built-in dataset

# %%
#To check which datasets are available
DataFrame=sns.get_dataset_names()
DataFrame
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
#To load a built_in dataset
Flight_DF=sns.load_dataset('flights')
Flight_DF
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# ##Some Basic Functions

# %%
#To Access first 5 rows of dataset
Flight_DF.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# Head function is used to access first rows from dataset. Any number of rows can be accessed.

# %%
#To access last 5 rows of dataset
Flight_DF.tail(5)
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %% [markdown]
# Tail function is used to show the last rows of dataset. Any number of rows can be accessed.

# %%
#To check shape of data
Flight_DF.shape
# Out:
# (144, 3)

# %% [markdown]
# 144 is number of rows in dataset and 3 is number of columns in dataset.

# %%
#To access a single coulum/series from dataset
Flight_DF['passengers']
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: passengers, Length: 144, dtype: int64

# %%
#To access two columns
Flight_DF[['passengers','month']]
# Out:
#      passengers month
# 0           112   Jan
# 1           118   Feb
# 2           132   Mar
# 3           129   Apr
# 4           121   May
# ..          ...   ...
# 139         606   Aug
# 140         508   Sep
# 141         461   Oct
# 142         390   Nov
# 143         432   Dec
#
# [144 rows x 2 columns]

# %%
#To access a specific row
Flight_DF.loc[4]
# Out:
# year          1949
# month          May
# passengers     121
# Name: 4, dtype: object

# %%
#To access more than one row with loc function
Flight_DF.loc[4:8]
# Out:
#    year month  passengers
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148
# 8  1949   Sep         136

# %% [markdown]
# Loc function is used for label indexing. It includes start and end position.

# %%
#To access more than one row with iloc function
Flight_DF.iloc[4:8]
# Out:
#    year month  passengers
# 4  1949   May         121
# 5  1949   Jun         135
# 6  1949   Jul         148
# 7  1949   Aug         148

# %% [markdown]
# iloc function is used to access rows based on integer location indexing. It doesn't include last position.

# %%
#To access specific rows and columns
Specific_Data=Flight_DF.iloc[0:5,:]
Specific_Data
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# The above code prints first 5 rows and all columns.

# %%
#To access 3rd row
Flight_DF.iloc[2]
# Out:
# year          1949
# month          Mar
# passengers     132
# Name: 2, dtype: object

# %%
#To check the summary of dataset
Flight_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
#To Find Descriptive Statistics of dataset
Flight_DF.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
#Filtering using a boolean condition
Filtered_Data=Flight_DF[Flight_DF['passengers']>500]
print(Filtered_Data)
# Out:
#      year month  passengers
# 115  1958   Aug         505
# 126  1959   Jul         548
# 127  1959   Aug         559
# 137  1960   Jun         535
# 138  1960   Jul         622
# 139  1960   Aug         606
# 140  1960   Sep         508

# %%
#To count unique values in a single column
counts=Flight_DF['passengers'].value_counts()
counts
# Out:
# passengers
# 229    3
# 306    2
# 405    2
# 242    2
# 196    2
#       ..
# 191    1
# 209    1
# 230    1
# 218    1
# 432    1
# Name: count, Length: 118, dtype: int64

# %%
#Data visualization
Flight_DF['passengers'].plot(kind='line')
# Out:
# <Axes: >

# %%
#Sorting DataFrame by a column
Flight_DF.sort_values(by='passengers')
# Out:
#      year month  passengers
# 10   1949   Nov         104
# 0    1949   Jan         112
# 22   1950   Nov         114
# 12   1950   Jan         115
# 1    1949   Feb         118
# ..    ...   ...         ...
# 137  1960   Jun         535
# 126  1959   Jul         548
# 127  1959   Aug         559
# 139  1960   Aug         606
# 138  1960   Jul         622
#
# [144 rows x 3 columns]

# %%
#Creating a DataFrame
New_Data={
    'Name':["Peter","John","Anna","Joseph","Lisa","Bella"],
    'Age':[28,30,26,24,29,33],
    'City':["Florida","New York","California","Boston","Dallas","Austin"]
}
#Coverting to DataFrame
df=pd.DataFrame(New_Data)
print(df)
# Out:
#      Name  Age        City
# 0   Peter   28     Florida
# 1    John   30    New York
# 2    Anna   26  California
# 3  Joseph   24      Boston
# 4    Lisa   29      Dallas
# 5   Bella   33      Austin

# %%
#Adding a new column
df['Degree']=["MSCS","MBA","BS Math","BBA","BSSE","MIT"]
df
# Out:
#      Name  Age        City   Degree
# 0   Peter   28     Florida     MSCS
# 1    John   30    New York      MBA
# 2    Anna   26  California  BS Math
# 3  Joseph   24      Boston      BBA
# 4    Lisa   29      Dallas     BSSE
# 5   Bella   33      Austin      MIT

# %%
#To access starting 2 rows
print(df)
print("_________________________________")
print(df.head(2))
# Out:
#      Name  Age        City   Degree
# 0   Peter   28     Florida     MSCS
# 1    John   30    New York      MBA
# 2    Anna   26  California  BS Math
# 3  Joseph   24      Boston      BBA
# 4    Lisa   29      Dallas     BSSE
# 5   Bella   33      Austin      MIT
# _________________________________
#     Name  Age      City Degree
# 0  Peter   28   Florida   MSCS
# 1   John   30  New York    MBA

# %%
#Dropping a column
df.drop("Degree",axis=1)
# Out:
#      Name  Age        City
# 0   Peter   28     Florida
# 1    John   30    New York
# 2    Anna   26  California
# 3  Joseph   24      Boston
# 4    Lisa   29      Dallas
# 5   Bella   33      Austin

# %%
#Creating another DataFrame
Data2={
 'City':["Florida","New York","California",None,"Dallas","Austin"],
 'Population':[87043,102347,47892,18530,None,54901]
}
df2=pd.DataFrame(Data2)
df2
# Out:
#          City  Population
# 0     Florida     87043.0
# 1    New York    102347.0
# 2  California     47892.0
# 3        None     18530.0
# 4      Dallas         NaN
# 5      Austin     54901.0

# %%
#Merging 2 DataFrames based on one common column
merged_df=pd.merge(df,df2,on='City')
merged_df
# Out:
#     Name  Age        City   Degree  Population
# 0  Peter   28     Florida     MSCS       87043
# 1   John   30    New York      MBA      102347
# 2   Anna   26  California  BS Math       47892
# 3   Lisa   29      Dallas     BSSE       18530
# 4  Bella   33      Austin      MIT       54901

# %% [markdown]
# All the rows with same data will be printed. A row that has 'None' value will be skippes. Merging will be based on only commen data.

# %%
#Handling Missing Values of df2
print(df2)
print("___________________________________________________")
df2_filled=df2.fillna({'City':'Boston','Population':'73109'})
print(df2_filled)
# Out:
#          City  Population
# 0     Florida     87043.0
# 1    New York    102347.0
# 2  California     47892.0
# 3        None     18530.0
# 4      Dallas         NaN
# 5      Austin     54901.0
# ___________________________________________________
#          City Population
# 0     Florida    87043.0
# 1    New York   102347.0
# 2  California    47892.0
# 3      Boston    18530.0
# 4      Dallas      73109
# 5      Austin    54901.0

# %%
#Dropping row with missing value
print(df2)
print("___________________________")
df2_dropped=df2.dropna()
print(df2_dropped)
# Out:
#          City  Population
# 0     Florida     87043.0
# 1    New York    102347.0
# 2  California     47892.0
# 3        None     18530.0
# 4      Dallas         NaN
# 5      Austin     54901.0
# ___________________________
#          City  Population
# 0     Florida     87043.0
# 1    New York    102347.0
# 2  California     47892.0
# 5      Austin     54901.0
